# %%
import pandas as pd

# %%
connector = 'mysql+mysqlconnector://192.168.1.30:3306/moviesdb'

# %%
pd.read_sql("show tables",con=connector)
# Out:
#   Tables_in_moviesdb
# 0             actors
# 1         financials
# 2          languages
# 3        movie_actor
# 4             movies

# %%
pd.read_sql('''select * from movies''',con=connector)
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
pd.read_sql('''select count(*) from movies''',con=connector)
# Out:
#    count(*)
# 0        39

# %%
pd.read_sql('''select count(*) from movies where industry like "hollywood"''',con=connector)
# Out:
#    count(*)
# 0        21

# %%
pd.read_sql('''select count(*) from movies where industry like "bollywood"''',con=connector)
# Out:
#    count(*)
# 0        18

# %%
pd.read_sql('''select distinct industry from movies''',con=connector)
# Out:
#     industry
# 0  Bollywood
# 1  Hollywood

# %%
x='''"%thor%"'''

# %%
pd.read_sql('''select * from movies where title like {}'''.format(x),con=connector)
# Out:
#    movie_id                    title   industry  release_year  imdb_rating  \
# 0       103    Thor: The Dark World   Hollywood          2013          6.8
# 1       104          Thor: Ragnarok   Hollywood          2017          7.9
# 2       105  Thor: Love and Thunder   Hollywood          2022          6.8
#
#            studio  language_id
# 0  Marvel Studios            5
# 1  Marvel Studios            5
# 2  Marvel Studios            5

# %%
pd.read_sql('''select * from movies where studio=""''',con=connector)
# Out:
#    movie_id             title   industry  release_year  imdb_rating studio  \
# 0       110  Bajirao Mastani   Bollywood          2015          7.2
# 1       124          Parasite  Hollywood          2019          8.5
# 2       128  Taare Zameen Par  Bollywood          2007          8.3
#
#    language_id
# 0            1
# 1            5
# 2            1
